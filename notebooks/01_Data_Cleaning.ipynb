# %% [markdown]
# # Pricing Elasticity Analysis
#
# ## Data Cleaning & Data Understanding
#
# **Objective:**
# Understand the dataset, assess its quality, and prepare it for exploratory data analysis.

# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option('display.max_columns', None)

df = pd.read_csv("../data/data/retail_price.csv")
df.head()
# Out:
#   product_id product_category_name  month_year  qty  total_price  \
# 0       bed1        bed_bath_table  01-05-2017    1        45.95
# 1       bed1        bed_bath_table  01-06-2017    3       137.85
# 2       bed1        bed_bath_table  01-07-2017    6       275.70
# 3       bed1        bed_bath_table  01-08-2017    4       183.80
# 4       bed1        bed_bath_table  01-09-2017    2        91.90
#
#    freight_price  unit_price  product_name_lenght  product_description_lenght  \
# 0      15.100000       45.95                   39                         161
# 1      12.933333       45.95                   39                         161
# 2      14.840000       45.95                   39                         161
# 3      14.287500       45.95                   39                         161
# 4      15.100000       45.95                   39                         161
#
#    product_photos_qty  product_weight_g  product_score  customers  weekday  \
# ...

# %%
df.shape
# Out:
# (676, 30)

# %%
df.columns
# Out:
# Index(['product_id', 'product_category_name', 'month_year', 'qty',
#        'total_price', 'freight_price', 'unit_price', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_score', 'customers', 'weekday', 'weekend', 'holiday', 'month',
#        'year', 's', 'volume', 'comp_1', 'ps1', 'fp1', 'comp_2', 'ps2', 'fp2',
#        'comp_3', 'ps3', 'fp3', 'lag_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  676 non-null    object
#  1   product_category_name       676 non-null    object
#  2   month_year                  676 non-null    object
#  3   qty                         676 non-null    int64
#  4   total_price                 676 non-null    float64
#  5   freight_price               676 non-null    float64
#  6   unit_price                  676 non-null    float64
#  7   product_name_lenght         676 non-null    int64
#  8   product_description_lenght  676 non-null    int64
#  9   product_photos_qty          676 non-null    int64
#  10  product_weight_g            676 non-null    int64
#  11  product_score               676 non-null    float64
#  12  customers                   676 non-null    int64
# ...

# %%
df.describe()
# Out:
#               qty   total_price  freight_price  unit_price  \
# count  676.000000    676.000000     676.000000  676.000000
# mean    14.495562   1422.708728      20.682270  106.496800
# std     15.443421   1700.123100      10.081817   76.182972
# min      1.000000     19.900000       0.000000   19.900000
# 25%      4.000000    333.700000      14.761912   53.900000
# 50%     10.000000    807.890000      17.518472   89.900000
# 75%     18.000000   1887.322500      22.713558  129.990000
# max    122.000000  12095.000000      79.760000  364.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count           676.000000                  676.000000          676.000000
# mean             48.720414                  767.399408            1.994083
# std               9.420715                  655.205015            1.420473
# min              29.000000                  100.000000            1.000000
# ...

# %%
df.tail()
# Out:
#     product_id product_category_name  month_year  qty  total_price  \
# 671       bed5        bed_bath_table  01-05-2017    1       215.00
# 672       bed5        bed_bath_table  01-06-2017   10      2090.00
# 673       bed5        bed_bath_table  01-07-2017   59     12095.00
# 674       bed5        bed_bath_table  01-08-2017   52     10375.00
# 675       bed5        bed_bath_table  01-09-2017   32      5222.36
#
#      freight_price  unit_price  product_name_lenght  \
# 671       8.760000  215.000000                   56
# 672      21.322000  209.000000                   56
# 673      22.195932  205.000000                   56
# 674      19.412885  199.509804                   56
# 675      24.324687  163.398710                   56
#
#      product_description_lenght  product_photos_qty  product_weight_g  \
# 671                         162                   5              9750
# 672                         162                   5              9750
# ...

# %% [markdown]
# ## Data Quality Assessment

# %%
df.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# month_year                    0
# qty                           0
# total_price                   0
# freight_price                 0
# unit_price                    0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_score                 0
# customers                     0
# weekday                       0
# weekend                       0
# holiday                       0
# month                         0
# year                          0
# s                             0
# volume                        0
# comp_1                        0
# ps1                           0
# fp1                           0
# comp_2                        0
# ps2                           0
# fp2                           0
# comp_3                        0
# ps3                           0
# fp3                           0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Findings
#
# - The dataset contains **676 rows** and **30 columns**.
# - No missing values were found.
# - Duplicate rows were checked.
# - The data is ready for exploratory data analysis.

# %% [markdown]
# ## Data Types

# %%
df.dtypes
# Out:
# product_id                     object
# product_category_name          object
# month_year                     object
# qty                             int64
# total_price                   float64
# freight_price                 float64
# unit_price                    float64
# product_name_lenght             int64
# product_description_lenght      int64
# product_photos_qty              int64
# product_weight_g                int64
# product_score                 float64
# customers                       int64
# weekday                         int64
# weekend                         int64
# holiday                         int64
# month                           int64
# year                            int64
# s                             float64
# volume                          int64
# comp_1                        float64
# ps1                           float64
# fp1                           float64
# comp_2                        float64
# ps2                           float64
# ...

# %%
df.nunique()
# Out:
# product_id                     52
# product_category_name           9
# month_year                     20
# qty                            66
# total_price                   573
# freight_price                 653
# unit_price                    280
# product_name_lenght            24
# product_description_lenght     46
# product_photos_qty              7
# product_weight_g               45
# product_score                  11
# customers                      94
# weekday                         4
# weekend                         3
# holiday                         5
# month                          12
# year                            2
# s                             450
# volume                         40
# comp_1                         88
# ps1                             9
# fp1                           179
# comp_2                        123
# ps2                            10
# fp2                           242
# comp_3                        105
# ...

# %%
df.sample(5)
# Out:
#      product_id  product_category_name  month_year  qty  total_price  \
# 152  computers5  computers_accessories  01-01-2018   57      5453.96
# 620  computers3  computers_accessories  01-12-2017    2       269.80
# 622  computers3  computers_accessories  01-02-2018    3       398.91
# 131     health8          health_beauty  01-04-2018   14      1119.86
# 371  furniture4        furniture_decor  01-01-2018   13      1298.70
#
#      freight_price  unit_price  product_name_lenght  \
# 152      12.239123   93.094894                   33
# 620      38.780000  134.900000                   42
# 622      14.596667  132.970000                   42
# 131      14.485000   79.990000                   59
# 371      22.819231   99.900000                   57
#
#      product_description_lenght  product_photos_qty  product_weight_g  \
# 152                         300                   1               207
# 620                         363                   1               922
# ...

# %% [markdown]
# ## Statistical Summary
#
# Let's analyze the statistical properties of the numerical features to understand their distribution, central tendency, and spread.

# %%
# Statistical summary
df.describe().T
# Out:
#                             count          mean          std          min  \
# qty                         676.0     14.495562    15.443421     1.000000
# total_price                 676.0   1422.708728  1700.123100    19.900000
# freight_price               676.0     20.682270    10.081817     0.000000
# unit_price                  676.0    106.496800    76.182972    19.900000
# product_name_lenght         676.0     48.720414     9.420715    29.000000
# product_description_lenght  676.0    767.399408   655.205015   100.000000
# product_photos_qty          676.0      1.994083     1.420473     1.000000
# product_weight_g            676.0   1847.498521  2274.808483   100.000000
# product_score               676.0      4.085503     0.232021     3.300000
# customers                   676.0     81.028107    62.055560     1.000000
# weekday                     676.0     21.773669     0.986104    20.000000
# weekend                     676.0      8.658284     0.705600     8.000000
# ...

# %% [markdown]
# ## Identify Numerical and Categorical Features

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print("Numerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# Index(['qty', 'total_price', 'freight_price', 'unit_price',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_score', 'customers',
#        'weekday', 'weekend', 'holiday', 'month', 'year', 's', 'volume',
#        'comp_1', 'ps1', 'fp1', 'comp_2', 'ps2', 'fp2', 'comp_3', 'ps3', 'fp3',
#        'lag_price'],
#       dtype='object')
#
# Categorical Columns:
# Index(['product_id', 'product_category_name', 'month_year'], dtype='object')

# %% [markdown]
# ## Target Variable: Quantity Sold (qty)

# %%
df["qty"].describe()
# Out:
# count    676.000000
# mean      14.495562
# std       15.443421
# min        1.000000
# 25%        4.000000
# 50%       10.000000
# 75%       18.000000
# max      122.000000
# Name: qty, dtype: float64

# %%
df["qty"].value_counts().head(10)
# Out:
# qty
# 1     48
# 2     46
# 6     42
# 3     39
# 4     37
# 13    31
# 11    30
# 5     29
# 7     28
# 9     27
# Name: count, dtype: int64
